# %%
from astropy.coordinates import get_sun
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
from astropy.coordinates import AltAz, EarthLocation, SkyCoord
from astropy.time import Time


#region Observatory
Piwnice = EarthLocation(lat=53 * u.deg, lon= 18*u.deg, height=70 * u.m)

class Object:
    def __init__(self, name, ra, dec):
        self.name = name
        self.ra = ra
        self.dec = dec



#file = np.loadtxt(r"C:\Users\Bazik\Desktop\BazikRepo\BasicPlot\data.txt")

list_of_objects = []
def ReadObjectsFromFile(path):
    with open(path, 'r') as file:
        for line in file:
            line = line.strip()
            if line:
                name, ra, dec = line.split()
                obj = Object(name, ra, dec)
                list_of_objects.append(obj)

    return list_of_objects

ReadObjectsFromFile(r"C:\Users\Bazik\Desktop\BazikRepo\BasicPlot\data.txt")
